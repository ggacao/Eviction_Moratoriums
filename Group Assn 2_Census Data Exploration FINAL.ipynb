# %%
import pandas as pd

# %%
income = pd.read_csv('../../data/Income_5Y2018.S1901_data_with_overlays_2020-10-17T192035.csv')

# %%
# load income data file
income.shape
# Out:
# (2347, 130)

# %%
# check size of data
income.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 2  1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 3  1400000US06037101210  Census Tract 1012.10, Los Angeles County, Cali...
# 4  1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
#
#                 S1901_C01_001E                          S1901_C01_001M  \
# 0  Estimate!!Households!!Total  Margin of Error!!Households MOE!!Total
# 1                         1596                                      88
# 2                         1256                                      79
# 3                         2321                                      79
# 4                         1294                                      54
#
#               S1901_C02_001E                        S1901_C02_001M  \
# ...

# %%
# see all the data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
income.sample()
# Out:
#                    GEO_ID                                               NAME  \
# 716  1400000US06037228500  Census Tract 2285, Los Angeles County, California
#
#     S1901_C01_001E S1901_C01_001M S1901_C02_001E S1901_C02_001M  \
# 716           1164             59           1003            106
#
#     S1901_C03_001E S1901_C03_001M S1901_C04_001E S1901_C04_001M  \
# 716            335            108            161             83
#
#     S1901_C01_002E S1901_C01_002M S1901_C02_002E S1901_C02_002M  \
# 716           10.1            5.7           11.6            6.1
#
#     S1901_C03_002E S1901_C03_002M S1901_C04_002E S1901_C04_002M  \
# 716            0.0            9.9           38.5           25.9
#
#     S1901_C01_003E S1901_C01_003M S1901_C02_003E S1901_C02_003M  \
# 716            1.6            1.6            2.7            3.3
#
#     S1901_C03_003E S1901_C03_003M S1901_C04_003E S1901_C04_003M  \
# 716            0.0            9.9           11.8           13.3
#
# ...

# %%
# check the data types
income.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2347 entries, 0 to 2346
# Data columns (total 130 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GEO_ID          2347 non-null   object
#  1   NAME            2347 non-null   object
#  2   S1901_C01_001E  2347 non-null   object
#  3   S1901_C01_001M  2347 non-null   object
#  4   S1901_C02_001E  2347 non-null   object
#  5   S1901_C02_001M  2347 non-null   object
#  6   S1901_C03_001E  2347 non-null   object
#  7   S1901_C03_001M  2347 non-null   object
#  8   S1901_C04_001E  2347 non-null   object
#  9   S1901_C04_001M  2347 non-null   object
#  10  S1901_C01_002E  2347 non-null   object
#  11  S1901_C01_002M  2347 non-null   object
#  12  S1901_C02_002E  2347 non-null   object
#  13  S1901_C02_002M  2347 non-null   object
#  14  S1901_C03_002E  2347 non-null   object
#  15  S1901_C03_002M  2347 non-null   object
#  16  S1901_C04_002E  2347 non-null   object
# ...

# %%
income.GEO_ID.head()
# Out:
# 0                      id
# 1    1400000US06037101110
# 2    1400000US06037101122
# 3    1400000US06037101210
# 4    1400000US06037101220
# Name: GEO_ID, dtype: object

# %%
# check how many columns have all null values
income.columns[income.isna().all()].tolist()
# Out:
# []

# %%
# list columns
columns = list(income)

# %%
columns
# Out:
# ['GEO_ID',
#  'NAME',
#  'S1901_C01_001E',
#  'S1901_C01_001M',
#  'S1901_C02_001E',
#  'S1901_C02_001M',
#  'S1901_C03_001E',
#  'S1901_C03_001M',
#  'S1901_C04_001E',
#  'S1901_C04_001M',
#  'S1901_C01_002E',
#  'S1901_C01_002M',
#  'S1901_C02_002E',
#  'S1901_C02_002M',
#  'S1901_C03_002E',
#  'S1901_C03_002M',
#  'S1901_C04_002E',
#  'S1901_C04_002M',
#  'S1901_C01_003E',
#  'S1901_C01_003M',
#  'S1901_C02_003E',
#  'S1901_C02_003M',
#  'S1901_C03_003E',
#  'S1901_C03_003M',
#  'S1901_C04_003E',
#  'S1901_C04_003M',
#  'S1901_C01_004E',
#  'S1901_C01_004M',
#  'S1901_C02_004E',
#  'S1901_C02_004M',
#  'S1901_C03_004E',
#  'S1901_C03_004M',
#  'S1901_C04_004E',
#  'S1901_C04_004M',
#  'S1901_C01_005E',
#  'S1901_C01_005M',
#  'S1901_C02_005E',
#  'S1901_C02_005M',
#  'S1901_C03_005E',
#  'S1901_C03_005M',
#  'S1901_C04_005E',
#  'S1901_C04_005M',
#  'S1901_C01_006E',
#  'S1901_C01_006M',
#  'S1901_C02_006E',
#  'S1901_C02_006M',
#  'S1901_C03_006E',
#  'S1901_C03_006M',
# ...

# %%
# rename columns
income.columns = ['GEO_ID',
 'NAME',
 'Total_Households',
 'MOE_Total_HH',
 'Total_Families',
 'MOE_Total_Families',
 'Total_Married Couples',
 'S1901_C03_001M',
 'Total_NonFamilyHH',
 'S1901_C04_001M',
 'Total_HH Less than 10K',
 'S1901_C01_002M',
 'Total_Families Less than 10K',
 'S1901_C02_002M',
 'Total_Married Couples Less than 10K',
 'S1901_C03_002M',
 'NonFamily_HH Less than 10K',
 'S1901_C04_002M',
 'Total_HH 10K to 14,999',
 'S1901_C01_003M',
 'Total_Families 10K to 14,999',
 'S1901_C02_003M',
 'Total_Married Couples 10k to 14,999',
 'S1901_C03_003M',
 'NonFamily HH 10K to 14,999',
 'S1901_C04_003M',
 'HH 15K to 24,999',
 'S1901_C01_004M',
 'Families 15K to 24,999',
 'S1901_C02_004M',
 'Married Couples 15K to 24,999',
 'S1901_C03_004M',
 'Nonfamily HH 15K ro 24,999',
 'S1901_C04_004M',
 'Total_HH 25K to 34,999',
 'S1901_C01_005M',
 'Total_Families 25K to 34,999',
 'S1901_C02_005M',
 'Married Couples 25K to 34,999',
 'S1901_C03_005M',
 'NonFamily HH 25K to 34,999',
 'S1901_C04_005M',
 'Total_HH 35K to 49,999',
 'S1901_C01_006M',
 'Total_Families 35K to 49,999',
 'S1901_C02_006M',
 'Married Couples 35K to 49,999',
 'S1901_C03_006M',
 'NonFamily HH 35K to 49,999',
 'S1901_C04_006M',
 'Total_HH 50K to 74,999',
 'S1901_C01_007M',
 'Total_Families 50K to 74,999',
 'S1901_C02_007M',
 'Married Couples 50K to 74,999',
 'S1901_C03_007M',
 'NonFamily HH 50K to 74,999',
 'S1901_C04_007M',
 'Total_HH 75K to 99,999',
 'S1901_C01_008M',
 'Total_Families 75K to 99,999',
 'S1901_C02_008M',
 'Married Couples 75K to 99,999',
 'S1901_C03_008M',
 'NonFamily HH 75K to 99,999',
 'S1901_C04_008M',
 'Total_HH 100K to 149,999',
 'S1901_C01_009M',
 'Total_Families 100K to 149,999',
 'S1901_C02_009M',
 'Married Couple Families 100K to 149,999',
 'S1901_C03_009M',
 'Nonfamily_HH 100K to 149,999',
 'S1901_C04_009M',
 'Total_HH 150K to 199,999',
 'S1901_C01_010M',
 'Total_Families 150K to 199,999',
 'S1901_C02_010M',
 'Married Couple Families 150K to 199,999',
 'S1901_C03_010M',
 'NonFamily HH 150K to 199,999',
 'S1901_C04_010M',
 'Total_HH more than 200K',
 'S1901_C01_011M',
 'Total_Families more than 200K',
 'S1901_C02_011M',
 'Married Couple Families more than 200K',
 'S1901_C03_011M',
 'Nonfamily HH more than 200K',
 'S1901_C04_011M',
 'HH Median Income',
 'S1901_C01_012M',
 'Families Median Income',
 'S1901_C02_012M',
 'Married Couple families Median Income',
 'S1901_C03_012M',
 'NonFamily Median Income',
 'S1901_C04_012M',
 'HH Mean Income',
 'S1901_C01_013M',
 'Families Mean Income',
 'S1901_C02_013M',
 'Married Couple Families Mean Income',
 'S1901_C03_013M',
 'Nonfamily Mean Income',
 'S1901_C04_013M',
 'PercentAllocated_HH income las 12 mos',
 'S1901_C01_014M',
 'S1901_C02_014E',
 'S1901_C02_014M',
 'S1901_C03_014E',
 'S1901_C03_014M',
 'S1901_C04_014E',
 'S1901_C04_014M',
 'S1901_C01_015E',
 'S1901_C01_015M',
 'PercentAllocated_Family income las 12 mos',
 'S1901_C02_015M',
 'S1901_C03_015E',
 'S1901_C03_015M',
 'S1901_C04_015E',
 'S1901_C04_015M',
 'S1901_C01_016E',
 'S1901_C01_016M',
 'S1901_C02_016E',
 'S1901_C02_016M',
 'S1901_C03_016E',
 'S1901_C03_016M',
 'PercentAllocated_Nonfamily income las 12 mos',
 'S1901_C04_016M']

# %%
# drop columns not needed
columns_to_drop = [ 'MOE_Total_HH','MOE_Total_Families','S1901_C03_001M','S1901_C01_002M','S1901_C02_002M','S1901_C03_002M','S1901_C04_002M','S1901_C01_003M','S1901_C02_003M','S1901_C03_003M','S1901_C04_003M','S1901_C01_004M','S1901_C02_004M','S1901_C03_004M','S1901_C04_004M','S1901_C01_005M','S1901_C02_005M','S1901_C03_005M','S1901_C04_005M','S1901_C01_006M','S1901_C02_006M','S1901_C03_006M','S1901_C04_006M','S1901_C01_007M','S1901_C02_007M','S1901_C03_007M','S1901_C04_007M','S1901_C01_008M','S1901_C02_008M','S1901_C03_008M','S1901_C04_008M','S1901_C01_009M','S1901_C02_009M','S1901_C03_009M','S1901_C04_009M','S1901_C01_010M', 'S1901_C02_010M', 'S1901_C03_010M', 'S1901_C04_010M', 'S1901_C01_011M', 'S1901_C02_011M', 'S1901_C03_011M', 'S1901_C04_011M', 'S1901_C01_012M', 'S1901_C02_012M', 'S1901_C03_012M', 'S1901_C04_012M', 'S1901_C01_013M', 'S1901_C02_013M', 'S1901_C03_013M', 'S1901_C04_013M', 'S1901_C01_014M', 'S1901_C02_014E', 'S1901_C02_014M', 'S1901_C03_014E', 'S1901_C03_014M', 'S1901_C04_014E', 'S1901_C04_014M', 'S1901_C01_015E', 'S1901_C01_015M', 'S1901_C02_015M', 'S1901_C03_015E', 'S1901_C03_015M', 'S1901_C04_015E', 'S1901_C04_015M', 'S1901_C01_016E', 'S1901_C01_016M', 'S1901_C02_016E', 'S1901_C02_016M', 'S1901_C03_016E', 'S1901_C03_016M', 'S1901_C04_016M']

# %%
# observe what columns look like again
income = income.drop(columns_to_drop,axis=1)
income.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 2  1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 3  1400000US06037101210  Census Tract 1012.10, Los Angeles County, Cali...
# 4  1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
#
#               Total_Households             Total_Families  \
# 0  Estimate!!Households!!Total  Estimate!!Families!!Total
# 1                         1596                       1000
# 2                         1256                        906
# 3                         2321                       1531
# 4                         1294                        881
#
#                       Total_Married Couples  \
# 0  Estimate!!Married-couple families!!Total
# 1                                       643
# ...

# %%
# observe data in HH Median income column
income['HH Median Income'].head()
# Out:
# 0    Estimate!!Households!!Median income (dollars)
# 1                                            53077
# 2                                            88953
# 3                                            32119
# 4                                            41728
# Name: HH Median Income, dtype: object

# %%
# observe some stats on column
income['HH Median Income'].describe()
# Out:
# count     2347
# unique    2195
# top          -
# freq        38
# Name: HH Median Income, dtype: object

# %%
# check how many rows are in data 
len(income)
# Out:
# 2347

# %%
# check how many columns have nulls values
income.isna().sum()
# Out:
# GEO_ID                                          0
# NAME                                            0
# Total_Households                                0
# Total_Families                                  0
# Total_Married Couples                           0
# Total_NonFamilyHH                               0
# S1901_C04_001M                                  0
# Total_HH Less than 10K                          0
# Total_Families Less than 10K                    0
# Total_Married Couples Less than 10K             0
# NonFamily_HH Less than 10K                      0
# Total_HH 10K to 14,999                          0
# Total_Families 10K to 14,999                    0
# Total_Married Couples 10k to 14,999             0
# NonFamily HH 10K to 14,999                      0
# HH 15K to 24,999                                0
# Families 15K to 24,999                          0
# Married Couples 15K to 24,999                   0
# Nonfamily HH 15K ro 24,999                      0
# ...

# %%
# sort census tracts that have highest percentage of HH Median Income less than 10K
income_sorted = income.sort_values(by='Total_HH Less than 10K',ascending=False)

# %%
# show rows/census tracts that have highest percentage of HH Median Income less than 10K, with certain columns
income_sorted[['NAME','Total_HH Less than 10K']].head(20)
# Out:
#                                                    NAME  \
# 0                                  Geographic Area Name
# 555   Census Tract 2086.10, Los Angeles County, Cali...
# 1043  Census Tract 3108, Los Angeles County, California
# 1031  Census Tract 3025.06, Los Angeles County, Cali...
# 922   Census Tract 2755, Los Angeles County, California
# 766   Census Tract 2371.01, Los Angeles County, Cali...
# 657   Census Tract 2187.02, Los Angeles County, Cali...
# 644   Census Tract 2170.01, Los Angeles County, Cali...
# 439   Census Tract 1916.20, Los Angeles County, Cali...
# 108   Census Tract 1152.02, Los Angeles County, Cali...
# 523   Census Tract 2046, Los Angeles County, California
# 743   Census Tract 2325, Los Angeles County, California
# 1441  Census Tract 4823.01, Los Angeles County, Cali...
# 1904  Census Tract 5754.01, Los Angeles County, Cali...
# 431   Census Tract 1912.03, Los Angeles County, Cali...
# 155   Census Tract 1211.02, Los Angeles County, Cali...
# ...

# %%
# sort data by Household median income, starting from lowest value
income_sorted = income.sort_values(by='HH Median Income',ascending=True)

# %%
# show data for household median income, starting from lowest value
income_sorted[['NAME','HH Median Income']].head(60)
# Out:
#                                                    NAME HH Median Income
# 2346  Census Tract 9903, Los Angeles County, California                -
# 2329  Census Tract 9800.14, Los Angeles County, Cali...                -
# 2197  Census Tract 9010.03, Los Angeles County, Cali...                -
# 2327  Census Tract 9800.10, Los Angeles County, Cali...                -
# 2326  Census Tract 9800.09, Los Angeles County, Cali...                -
# 2325  Census Tract 9800.08, Los Angeles County, Cali...                -
# 2324  Census Tract 9800.07, Los Angeles County, Cali...                -
# 2323  Census Tract 9800.06, Los Angeles County, Cali...                -
# 2322  Census Tract 9800.05, Los Angeles County, Cali...                -
# 2321  Census Tract 9800.04, Los Angeles County, Cali...                -
# 2320  Census Tract 9800.03, Los Angeles County, Cali...                -
# 2319  Census Tract 9800.02, Los Angeles County, Cali...                -
# ...

# %%
import pandas as pd

# %%
#import education dataframe
education = pd.read_csv('../data/Education_5Y2018(1).csv')

# %%
# observe size of data
education.shape
# Out:
# (2346, 63)

# %%
# observe size, columns, and rows of data
education.head()
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037101110  14000US06037101110  Census Tract 1011.10
# 1  6037101122  14000US06037101122  Census Tract 1011.22
# 2  6037101210  14000US06037101210  Census Tract 1012.10
# 3  6037101220  14000US06037101220  Census Tract 1012.20
# 4  6037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  Geo_PUMA5  Geo_PUMA1  \
# 0            0      ACSSF          3870     NaN  ...        NaN        NaN
# ...

# %%
# look at the data types
education.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 63 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2346 non-null   int64
#  1   Geo_GEOID      2346 non-null   object
#  2   Geo_NAME       2346 non-null   object
#  3   Geo_QName      2346 non-null   object
#  4   Geo_STUSAB     2346 non-null   object
#  5   Geo_SUMLEV     2346 non-null   int64
#  6   Geo_GEOCOMP    2346 non-null   int64
#  7   Geo_FILEID     2346 non-null   object
#  8   Geo_LOGRECNO   2346 non-null   int64
#  9   Geo_US         0 non-null      float64
#  10  Geo_REGION     0 non-null      float64
#  11  Geo_DIVISION   0 non-null      float64
#  12  Geo_STATECE    0 non-null      float64
#  13  Geo_STATE      2346 non-null   int64
#  14  Geo_COUNTY     2346 non-null   int64
#  15  Geo_COUSUB     0 non-null      float64
#  16  Geo_PLACE      0 non-null      float64
# ...

# %%
# obesrve values under Geo_STATE column
education.Geo_STATE.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Geo_STATE, dtype: int64

# %%
# obesrve values under Geo_COUNTY column
education.Geo_COUNTY.head()
# Out:
# 0    37
# 1    37
# 2    37
# 3    37
# 4    37
# Name: Geo_COUNTY, dtype: int64

# %%
# assign data types upon import
education = pd.read_csv(
    '../data/Education_5Y2018(1).csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    })

# %%
# continue assigning data types upon import
education['Geo_FIPS'] = education['Geo_FIPS'].str.zfill(11)

# %%
# continue assigning data types upon import
education['Geo_STATE'] = education['Geo_STATE'].str.zfill(11)

# %%
# continue assigning data types upon import
education['Geo_COUNTY'] = education['Geo_COUNTY'].str.zfill(11)

# %%
# observe data again to ensure zero is in front of values
education.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  Geo_PUMA5  Geo_PUMA1  \
# 0            0      ACSSF          3870     NaN  ...        NaN        NaN
# ...

# %%
# confirm new datatypes
education.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 63 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2346 non-null   object
#  1   Geo_GEOID      2346 non-null   object
#  2   Geo_NAME       2346 non-null   object
#  3   Geo_QName      2346 non-null   object
#  4   Geo_STUSAB     2346 non-null   object
#  5   Geo_SUMLEV     2346 non-null   int64
#  6   Geo_GEOCOMP    2346 non-null   int64
#  7   Geo_FILEID     2346 non-null   object
#  8   Geo_LOGRECNO   2346 non-null   int64
#  9   Geo_US         0 non-null      float64
#  10  Geo_REGION     0 non-null      float64
#  11  Geo_DIVISION   0 non-null      float64
#  12  Geo_STATECE    0 non-null      float64
#  13  Geo_STATE      2346 non-null   object
#  14  Geo_COUNTY     2346 non-null   object
#  15  Geo_COUSUB     0 non-null      float64
#  16  Geo_PLACE      0 non-null      float64
# ...

# %%
# list columns that have all null values
education.columns[education.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
# drop columns above with all null values
education = education.dropna(axis=1,how="all")

# %%
# check columns now listed in data after dropping those with all null values
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       2346 non-null   object
#  1   Geo_GEOID      2346 non-null   object
#  2   Geo_NAME       2346 non-null   object
#  3   Geo_QName      2346 non-null   object
#  4   Geo_STUSAB     2346 non-null   object
#  5   Geo_SUMLEV     2346 non-null   int64
#  6   Geo_GEOCOMP    2346 non-null   int64
#  7   Geo_FILEID     2346 non-null   object
#  8   Geo_LOGRECNO   2346 non-null   int64
#  9   Geo_STATE      2346 non-null   object
#  10  Geo_COUNTY     2346 non-null   object
#  11  Geo_TRACT      2346 non-null   int64
#  12  SE_A12001_001  2346 non-null   int64
#  13  SE_A12001_002  2346 non-null   int64
#  14  SE_A12001_003  2346 non-null   int64
#  15  SE_A12001_004  2346 non-null   int64
#  16  SE_A12001_005  2346 non-null   int64
# ...

# %%
# reinspect data
education.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO    Geo_STATE   Geo_COUNTY  Geo_TRACT  \
# 0            0      ACSSF          3870  00000000006  00000000037     101110
# ...

# %%
# identify columns to drop, by name
columns_to_drop = ['Geo_GEOID','Geo_STUSAB','Geo_SUMLEV','Geo_GEOCOMP','Geo_FILEID','Geo_LOGRECNO']

# %%
# drop columns above
education = education.drop(columns_to_drop,axis=1)
education.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName    Geo_STATE  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...  00000000006
# 1  Census Tract 1011.22, Los Angeles County, Cali...  00000000006
# 2  Census Tract 1012.10, Los Angeles County, Cali...  00000000006
# 3  Census Tract 1012.20, Los Angeles County, Cali...  00000000006
# 4  Census Tract 1013, Los Angeles County, California  00000000006
#
#     Geo_COUNTY  Geo_TRACT  SE_A12001_001  SE_A12001_002  SE_A12001_003  \
# 0  00000000037     101110           3085            524            765
# 1  00000000037     101122           2597            168            749
# 2  00000000037     101210           4107            762           1185
# ...

# %%
# create list of columns and their names
columns = list(education)

# %%
columns
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_A12001_001',
#  'SE_A12001_002',
#  'SE_A12001_003',
#  'SE_A12001_004',
#  'SE_A12001_005',
#  'SE_A12001_006',
#  'SE_A12001_007',
#  'SE_A12001_008']

# %%
# rename columns
education.columns = ['FIPS',
 'Geo_NAME',
 'Geo_QName',
 'Geo_STATE',
 'Geo_COUNTY',
 'Geo_TRACT',
 'Pop 25 yrs and over',
 'Less than HS',
 'HS Grad',
 'Some College',
 'Bachelors',
 'Masters',
 'Professional School',
 'Doctorate']

# %%
# reinspect data 
education.head()
# Out:
#           FIPS              Geo_NAME  \
# 0  06037101110  Census Tract 1011.10
# 1  06037101122  Census Tract 1011.22
# 2  06037101210  Census Tract 1012.10
# 3  06037101220  Census Tract 1012.20
# 4  06037101300     Census Tract 1013
#
#                                            Geo_QName    Geo_STATE  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...  00000000006
# 1  Census Tract 1011.22, Los Angeles County, Cali...  00000000006
# 2  Census Tract 1012.10, Los Angeles County, Cali...  00000000006
# 3  Census Tract 1012.20, Los Angeles County, Cali...  00000000006
# 4  Census Tract 1013, Los Angeles County, California  00000000006
#
#     Geo_COUNTY  Geo_TRACT  Pop 25 yrs and over  Less than HS  HS Grad  \
# 0  00000000037     101110                 3085           524      765
# 1  00000000037     101122                 2597           168      749
# 2  00000000037     101210                 4107           762     1185
# ...

# %%
# Define header
education['Masters'].head()
# Out:
# 0    180
# 1    248
# 2    174
# 3    129
# 4    278
# Name: Masters, dtype: int64

# %%
education['Masters'].mean()
# Out:
# 217.43563512361467

# %%
# Basic Stats
education['Masters'].describe()
# Out:
# count    2346.000000
# mean      217.435635
# std       218.291336
# min         0.000000
# 25%        51.000000
# 50%       145.000000
# 75%       321.000000
# max      1821.000000
# Name: Masters, dtype: float64

# %%
# plot histogram with 50 bins
education['Masters'].plot.hist(bins=50)

# %%
# Define header
education['HS Grad'].head()
# Out:
# 0     765
# 1     749
# 2    1185
# 3     700
# 4     949
# Name: HS Grad, dtype: int64

# %%
education['HS Grad'].mean()
# Out:
# 603.7860187553282

# %%
# Basic Stats
education['HS Grad'].describe()
# Out:
# count    2346.000000
# mean      603.786019
# std       317.131922
# min         0.000000
# 25%       377.000000
# 50%       575.000000
# 75%       798.750000
# max      2015.000000
# Name: HS Grad, dtype: float64

# %%
# plot histogram with 50 bins
education['HS Grad'].plot.hist(bins=50)

# %%
# how many rows we have
len(education)
# Out:
# 2346

# %%
# show rows with null columns
education[education['Bachelors'].isnull()]
# Out:
# Empty DataFrame
# Columns: [FIPS, Geo_NAME, Geo_QName, Geo_STATE, Geo_COUNTY, Geo_TRACT, Pop 25 yrs and over, Less than HS, HS Grad, Some College, Bachelors, Masters, Professional School, Doctorate]
# Index: []

# %%
# sort data by highest census tract with HS Graduates
education_sorted = education.sort_values(by='HS Grad',ascending = False)

# %%
# display 10 rows of data
education_sorted[['Geo_NAME','HS Grad']].head(10)
# Out:
#                   Geo_NAME  HS Grad
# 531   Census Tract 2060.20     2015
# 2197  Census Tract 9010.04     1903
# 536      Census Tract 2063     1769
# 2235  Census Tract 9107.05     1742
# 1421  Census Tract 4814.02     1695
# 1727     Census Tract 5503     1658
# 1483     Census Tract 5022     1657
# 2205  Census Tract 9012.05     1654
# 1492  Census Tract 5028.01     1642
# 1307     Census Tract 4325     1634

# %%
# plot it
education_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='HS Grad')

# %%
# Including Title
education_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='HS Grad', 
                            title='Top 10 Census Tracts with Highest HS Graduation Rates in LA County')

# %%
import geopandas as gpd

# %%
# read in a geojson file downloaded from the LA Times
tracts=gpd.read_file('../../up206a/data/la_tracts.geojson')
tracts.head()
# Out:
#                   kind  external_id         name  \
# 0  Census Tract (2012)  06037101110  06037101110
# 1  Census Tract (2012)  06037101122  06037101122
# 2  Census Tract (2012)  06037101210  06037101210
# 3  Census Tract (2012)  06037101220  06037101220
# 4  Census Tract (2012)  06037101300  06037101300
#
#                             slug                                    set  \
# 0  06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1  06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2  06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 3  06037101220-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 4  06037101300-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
#
#                                             metadata  \
# 0  {'INTPTLAT': '+34.2594737', 'NAME': '1011.10',...
# 1  {'INTPTLAT': '+34.2677213', 'NAME': '1011.22',...
# 2  {'INTPTLAT': '+34.2529724', 'NAME': '1012.10',...
# ...

# %%
# tell me more about this dataset
tracts.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          2346 non-null   object
#  1   external_id   2346 non-null   object
#  2   name          2346 non-null   object
#  3   slug          2346 non-null   object
#  4   set           2346 non-null   object
#  5   metadata      2346 non-null   object
#  6   resource_uri  2346 non-null   object
#  7   geometry      2346 non-null   geometry
# dtypes: geometry(1), object(7)
# memory usage: 146.8+ KB

# %%
# subset the data
tracts = tracts[['name','geometry']]
tracts.head()
# Out:
#           name                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
# rename the columns
tracts.columns = ['FIPS','geometry']

# %%
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
tracts.plot(figsize=(12,10))

# %%
# create a new dataframe based on the join
tracts_education=tracts.merge(education,on="FIPS")

# %%
tracts_education.plot(figsize=(12,10),
                 column='HS Grad',
                 legend=True, 
                 scheme='NaturalBreaks')

# %%
# load Race census data
race = pd.read_csv('../..//up206a/homework/Census/censusrace.B02001_data_with_overlays_2020-10-24T190556.csv')

# %%
# data shape exploration, rows and headers
race.shape
# Out:
# (8058, 22)

# %%
race.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US06059052511     Census Tract 525.11, Orange County, California
# 2  1400000US06037127520  Census Tract 1275.20, Los Angeles County, Cali...
# 3  1400000US06107001400         Census Tract 14, Tulare County, California
# 4  1400000US06067008113  Census Tract 81.13, Sacramento County, California
#
#        B02001_001E             B02001_001M                   B02001_002E  \
# 0  Estimate!!Total  Margin of Error!!Total  Estimate!!Total!!White alone
# 1             6295                     404                          3674
# 2             4544                     368                           869
# 3             5202                     456                          4451
# 4             3626                     215                          3095
#
#                            B02001_002M  \
# ...

# %%
# Show all the data 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
race.sample()
# Out:
#                     GEO_ID                                           NAME  \
# 1847  1400000US06001433000  Census Tract 4330, Alameda County, California
#
#      B02001_001E B02001_001M B02001_002E B02001_002M B02001_003E B02001_003M  \
# 1847        3661         575        1549         336         243         146
#
#      B02001_004E B02001_004M B02001_005E B02001_005M B02001_006E B02001_006M  \
# 1847          28          42        1471         592           7          10
#
#      B02001_007E B02001_007M B02001_008E B02001_008M B02001_009E B02001_009M  \
# 1847         177         122         186         123          29          45
#
#      B02001_010E B02001_010M
# 1847         157         115

# %%
# Looking at the data type
race.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8058 entries, 0 to 8057
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEO_ID       8058 non-null   object
#  1   NAME         8058 non-null   object
#  2   B02001_001E  8058 non-null   object
#  3   B02001_001M  8058 non-null   object
#  4   B02001_002E  8058 non-null   object
#  5   B02001_002M  8058 non-null   object
#  6   B02001_003E  8058 non-null   object
#  7   B02001_003M  8058 non-null   object
#  8   B02001_004E  8058 non-null   object
#  9   B02001_004M  8058 non-null   object
#  10  B02001_005E  8058 non-null   object
#  11  B02001_005M  8058 non-null   object
#  12  B02001_006E  8058 non-null   object
#  13  B02001_006M  8058 non-null   object
#  14  B02001_007E  8058 non-null   object
#  15  B02001_007M  8058 non-null   object
#  16  B02001_008E  8058 non-null   object
#  17  B02001_008M  8058 non-null   object
# ...

# %%
# Looking at the GEO identification column
race.GEO_ID.head()
# Out:
# 0                      id
# 1    1400000US06059052511
# 2    1400000US06037127520
# 3    1400000US06107001400
# 4    1400000US06067008113
# Name: GEO_ID, dtype: object

# %%
race.NAME.head()
# Out:
# 0                                 Geographic Area Name
# 1       Census Tract 525.11, Orange County, California
# 2    Census Tract 1275.20, Los Angeles County, Cali...
# 3           Census Tract 14, Tulare County, California
# 4    Census Tract 81.13, Sacramento County, California
# Name: NAME, dtype: object

# %%
columns = list(race)
columns
# Out:
# ['GEO_ID',
#  'NAME',
#  'B02001_001E',
#  'B02001_001M',
#  'B02001_002E',
#  'B02001_002M',
#  'B02001_003E',
#  'B02001_003M',
#  'B02001_004E',
#  'B02001_004M',
#  'B02001_005E',
#  'B02001_005M',
#  'B02001_006E',
#  'B02001_006M',
#  'B02001_007E',
#  'B02001_007M',
#  'B02001_008E',
#  'B02001_008M',
#  'B02001_009E',
#  'B02001_009M',
#  'B02001_010E',
#  'B02001_010M']

# %%
race.columns = ['GEO_ID',
 'NAME',
 'EstimateTotal',
 'MarginofErrorTotal',
 'EstimateTotalWhiteAlone',
 'MarginofErrorTotalWhite',
 'EstimateTotalBlack',
 'MarginofErrorBlack',
 'EstimateTotalNativeAm',
 'MarginofErrorNativeAm',
 'EstimateTotalAsian',
 'MarginofErrorAsian',
 'EstimateTotalNativeHawaiian',
 'MarginofErrorNativeHawaiian',
 'EstimateTotalOtherRace',
 'MarginofErrorOtherRace',
 'EstimateTotalTwoRaces',
 'MarginofErrorTwoRaces',
 'EstimateTotalTwoRacesPlusOther',
 'MarginofErrorTwoRacesPlusOther' , 
 'EstimateTotalTwoRacesandThreeorMore',
 'MarginofErrorTwoRacesandThreeorMore']

# %%
race.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0                    id                               Geographic Area Name
# 1  1400000US06059052511     Census Tract 525.11, Orange County, California
# 2  1400000US06037127520  Census Tract 1275.20, Los Angeles County, Cali...
# 3  1400000US06107001400         Census Tract 14, Tulare County, California
# 4  1400000US06067008113  Census Tract 81.13, Sacramento County, California
#
#      EstimateTotal      MarginofErrorTotal       EstimateTotalWhiteAlone  \
# 0  Estimate!!Total  Margin of Error!!Total  Estimate!!Total!!White alone
# 1             6295                     404                          3674
# 2             4544                     368                           869
# 3             5202                     456                          4451
# 4             3626                     215                          3095
#
#                MarginofErrorTotalWhite  \
# ...

# %%
# Looking at Total Estimate column
race['EstimateTotal'].head()
# Out:
# 0    Estimate!!Total
# 1               6295
# 2               4544
# 3               5202
# 4               3626
# Name: EstimateTotal, dtype: object

# %%
race['EstimateTotal'].describe()
# Out:
# count     8058
# unique    4722
# top          0
# freq        45
# Name: EstimateTotal, dtype: object

# %%
race = race.drop([0], axis=0)

# %%
race.head()
# Out:
#                  GEO_ID                                               NAME  \
# 1  1400000US06059052511     Census Tract 525.11, Orange County, California
# 2  1400000US06037127520  Census Tract 1275.20, Los Angeles County, Cali...
# 3  1400000US06107001400         Census Tract 14, Tulare County, California
# 4  1400000US06067008113  Census Tract 81.13, Sacramento County, California
# 5  1400000US06071000824  Census Tract 8.24, San Bernardino County, Cali...
#
#   EstimateTotal MarginofErrorTotal EstimateTotalWhiteAlone  \
# 1          6295                404                    3674
# 2          4544                368                     869
# 3          5202                456                    4451
# 4          3626                215                    3095
# 5          5401                393                    3142
#
#   MarginofErrorTotalWhite EstimateTotalBlack MarginofErrorBlack  \
# 1                     395                109                153
# ...

# %%
race['EstimateTotal'].head()
# Out:
# 1    6295
# 2    4544
# 3    5202
# 4    3626
# 5    5401
# Name: EstimateTotal, dtype: object

# %%
race['EstimateTotal'].describe()
# Out:
# count     8057
# unique    4721
# top          0
# freq        45
# Name: EstimateTotal, dtype: object

# %%
# Description of Total White population
race['EstimateTotalWhiteAlone'].describe()
# Out:
# count     8057
# unique    4227
# top          0
# freq        49
# Name: EstimateTotalWhiteAlone, dtype: object

# %%
# Description of Total Black population
race['EstimateTotalBlack'].describe()
# Out:
# count     8057
# unique    1287
# top          0
# freq       558
# Name: EstimateTotalBlack, dtype: object

# %%
# Decription of Total Asian Population 
race['EstimateTotalAsian'].describe()
# Out:
# count     8057
# unique    2170
# top          0
# freq       273
# Name: EstimateTotalAsian, dtype: object

# %%
#how many rows
len(race)
# Out:
# 8057

# %%
# null values in the data for a all columns
race.isna().sum()
# Out:
# GEO_ID                                 0
# NAME                                   0
# EstimateTotal                          0
# MarginofErrorTotal                     0
# EstimateTotalWhiteAlone                0
# MarginofErrorTotalWhite                0
# EstimateTotalBlack                     0
# MarginofErrorBlack                     0
# EstimateTotalNativeAm                  0
# MarginofErrorNativeAm                  0
# EstimateTotalAsian                     0
# MarginofErrorAsian                     0
# EstimateTotalNativeHawaiian            0
# MarginofErrorNativeHawaiian            0
# EstimateTotalOtherRace                 0
# MarginofErrorOtherRace                 0
# EstimateTotalTwoRaces                  0
# MarginofErrorTwoRaces                  0
# EstimateTotalTwoRacesPlusOther         0
# MarginofErrorTwoRacesPlusOther         0
# EstimateTotalTwoRacesandThreeorMore    0
# MarginofErrorTwoRacesandThreeorMore    0
# dtype: int64

# %%
# Census tracts sorted by Estimated Total Population 
race_sorted = race.sort_values(by='EstimateTotal',ascending = False)

# %%
race_sorted[['NAME','EstimateTotal']].head(10)
# Out:
#                                                    NAME EstimateTotal
# 40    Census Tract 427.33, Riverside County, California          9995
# 3540  Census Tract 185.13, San Diego County, California          9969
# 3175  Census Tract 192.07, San Diego County, California          9967
# 2047  Census Tract 63.02, San Bernardino County, Cal...          9962
# 1714       Census Tract 2.02, Plumas County, California           994
# 3662    Census Tract 1514.02, Sonoma County, California          9917
# 1141       Census Tract 3.04, Merced County, California          9911
# 1782     Census Tract 761.01, Orange County, California          9904
# 546      Census Tract 866.01, Orange County, California          9893
# 256   Census Tract 30.01, Stanislaus County, California          9890

# %%
# Cynthia Bourjac & Gerrlyn Gacao
# Cynthia explored the data set for Race and conducted the second half of the education exploration beginning with defining header [Master].
# Gerrlyn explored the data set for Income and conducted the first half of the education exploration set that ended with renaming columns.
